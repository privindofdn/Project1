# %%
# Import library yang dibutuhkan
import datetime
import pandas as pd
import matplotlib.pyplot as plt
# Baca dataset retail_raw_reduced.csv
dataset = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced.csv')
# Buat kolom order_month
dataset['order_month'] = dataset['order_date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").strftime('%Y-%m'))
# Buat kolom gmv
dataset['gmv'] = dataset['item_price'] * dataset['quantity']
# Plot grafik sesuai dengan instruksi
plt.figure(figsize=(10, 5))
dataset[dataset['order_month']=='2019-12'].groupby(['order_date'])['customer_id'].nunique().plot(color='red', marker='.', linewidth=2)
plt.title('Daily Number of Customers - December 2019', loc='left', pad=30, fontsize=20, color='orange')
plt.xlabel('Order Date', fontsize=15, color='blue')
plt.ylabel('Number of Customers', fontsize=15, color='blue')
plt.grid(color='darkgray', linestyle=':', linewidth=0.5)
plt.ylim(ymin=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-aae98ada0fc0> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 # Baca dataset retail_raw_reduced.csv
# ----> 6 dataset = pd.read_csv('https://dqlab-dataset.s3-ap-southeast-1.amazonaws.com/retail_raw_reduced.csv')
#       7 # Buat kolom order_month
#       8 dataset['order_month'] = dataset['order_date'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%d").strftime('%Y-%m'))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Membaca dataset
df = pd.read_csv('retail_raw_reduced.csv')

# Mengubah tipe data pada kolom 'order_date' menjadi datetime
df['order_date'] = pd.to_datetime(df['order_date'])

# Mengambil data hanya untuk bulan Desember
december_data = df[df['order_date'].dt.month == 12]

# Menghitung jumlah unique customers per tanggal
daily_customers = december_data.groupby(december_data['order_date'].dt.day)['customer_id'].nunique()

# Membuat line chart
plt.figure(figsize=(10, 5))
plt.plot(daily_customers.index, daily_customers.values, marker='o')
plt.title('Daily Number of Customers in December')
plt.xlabel('Date')
plt.ylabel('Number of Customers')
plt.xticks(range(1, 32))
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-44b39a9c2fea> in <cell line: 5>()
#       3
#       4 # Membaca dataset
# ----> 5 df = pd.read_csv('retail_raw_reduced.csv')
#       6
#       7 # Mengubah tipe data pada kolom 'order_date' menjadi datetime
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah produk terjual per brand
brand_product_count = df_dec.groupby('brand')['product_id'].nunique().reset_index()

# Mengurutkan brand berdasarkan jumlah produk terjual secara descending
brand_product_count_sorted = brand_product_count.sort_values('product_id', ascending=False)

# Membuat bar chart
plt.figure(figsize=(10, 5))
plt.bar(brand_product_count_sorted['brand'], brand_product_count_sorted['product_id'])
plt.xlabel('Brand')
plt.ylabel('Jumlah Produk Terjual')
plt.title('Jumlah Produk Terjual per Brand di Bulan Desember 2019')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c923a0eb7fdf> in <cell line: 4>()
#       2
#       3 # Menghitung jumlah produk terjual per brand
# ----> 4 brand_product_count = df_dec.groupby('brand')['product_id'].nunique().reset_index()
#       5
#       6 # Mengurutkan brand berdasarkan jumlah produk terjual secara descending
#
# NameError: name 'df_dec' is not defined

# %%
# Filter data untuk produk yang terjual di atas dan di bawah 100
df_dec_above_100 = df_dec[df_dec['quantity'] >= 100]
df_dec_below_100 = df_dec[df_dec['quantity'] < 100]

# Menghitung jumlah produk terjual di atas dan di bawah 100 per brand
brand_product_count_above_100 = df_dec_above_100.groupby('brand')['product_id'].count().reset_index()
brand_product_count_below_100 = df_dec_below_100.groupby('brand')['product_id'].count().reset_index()

# Menggabungkan data di atas menjadi satu dataframe
brand_product_count_stacked = pd.merge(brand_product_count_above_100, brand_product_count_below_100, on='brand', how='outer').fillna(0)

# Membuat stacked chart
plt.figure(figsize=(10, 5))
plt.bar(brand_product_count_stacked['brand'], brand_product_count_stacked['product_id_x'], label='>= 100')
plt.bar(brand_product_count_stacked['brand'], brand_product_count_stacked['product_id_y'], label='< 100', bottom=brand_product_count
# Out:
#   File "<ipython-input-2-09b48e8ad613>", line 15
#     plt.bar(brand_product_count_stacked['brand'], brand_product_count_stacked['product_id_y'], label='< 100', bottom=brand_product_count
#                                                                                                                                         ^
# SyntaxError: incomplete input
